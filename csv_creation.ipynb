# %%
import cv2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import colors
from sklearn.cluster import KMeans

# %%
image = cv2.imread("DATASET/A1/c1/r1/images/e0/c1r1e0n1.tif")
image3 = cv2.imread("DATASET/A1/c3/r1/images/e0/c3r1e0n1.tif")
image4 = cv2.imread("DATASET/A1/c4/r1/images/e0/c4r1e0n1.tif")
image5 = cv2.imread("DATASET/A1/c1/r1/images/e0/c1r1e0n2.tif")
image6 = cv2.imread("DATASET/A1/c3/r1/images/e0/c3r1e0n2.tif")

# Grayscale to binary

(thresh, blackAndWhiteImage) = cv2.threshold(image, 127, 255, cv2.THRESH_BINARY)
(thresh, blackAndWhiteImage4) = cv2.threshold(image3, 127, 255, cv2.THRESH_BINARY)

# %%
plt.imshow(image)
plt.show()
plt.imshow(image3)
plt.show()
plt.imshow(image4)
plt.show()

# %%
from sewar.full_ref import mse, sam, psnr, uqi, ssim, ergas, scc, rase, sam, msssim, vifp

print("MSE: ", sam(image,image3))
print("MSE: ", sam(image,image4))
print("MSE: ", sam(image,image5))
print("MSE: ", sam(image3,image6))
# Out:
# MSE:  0.2612010898675688
# MSE:  0.514152235327269
# MSE:  0.06706236625193535
# MSE:  0.3753178833870227

# %%
df = pd.read_csv("A1.csv")
df.head()
# Out:
#    Unnamed: 0                                    paths  c  r  e  n
# 0           0  DATASET/A1/c1/r1/images/e0/c1r1e0n1.tif  1  1  0  1
# 1           1  DATASET/A1/c1/r1/images/e0/c1r1e0n2.tif  1  1  0  2
# 2           2  DATASET/A1/c1/r1/images/e0/c1r1e0n3.tif  1  1  0  3
# 3           3  DATASET/A1/c1/r1/images/e0/c1r1e0n4.tif  1  1  0  4
# 4           4  DATASET/A1/c1/r1/images/e0/c1r1e0n5.tif  1  1  0  5
